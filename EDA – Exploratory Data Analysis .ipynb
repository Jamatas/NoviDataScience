# %% [markdown]
# # NOVI Bootcamp Data Engineer
# ### Data Science met Python

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### EDA - Exploratory Data Analysis
# ### Dataset: ‘The World Development Indicators’ van de World Bank

# %%
# !ls Dataset-World-Bank/
# Out:
# Country.csv      Footnotes.csv    Series.csv
# CountryNotes.csv Indicators.csv   SeriesNotes.csv

# %% [markdown]
# ### Country.csv

# %%
df_Country = pd.read_csv('Dataset-World-Bank/Country.csv')

# %%
print('Number of columns', len(df_Country.dtypes))
df_Country.dtypes
# Out:
# Number of columns 31
# CountryCode                                    object
# ShortName                                      object
# TableName                                      object
# LongName                                       object
# Alpha2Code                                     object
# CurrencyUnit                                   object
# SpecialNotes                                   object
# Region                                         object
# IncomeGroup                                    object
# Wb2Code                                        object
# NationalAccountsBaseYear                       object
# NationalAccountsReferenceYear                  object
# SnaPriceValuation                              object
# LendingCategory                                object
# OtherGroups                                    object
# SystemOfNationalAccounts                       object
# AlternativeConversionFactor                    object
# ...

# %%
print('shape: %d rows x %d columns' % df_Country.shape)
# Out:
# shape: 247 rows x 31 columns

# %%
df_Country
# Out:
#     CountryCode                 ShortName                 TableName  \
# 0           AFG               Afghanistan               Afghanistan
# 1           ALB                   Albania                   Albania
# 2           DZA                   Algeria                   Algeria
# 3           ASM            American Samoa            American Samoa
# 4           ADO                   Andorra                   Andorra
# 5           AGO                    Angola                    Angola
# 6           ATG       Antigua and Barbuda       Antigua and Barbuda
# 7           ARB                Arab World                Arab World
# 8           ARG                 Argentina                 Argentina
# 9           ARM                   Armenia                   Armenia
# 10          ABW                     Aruba                     Aruba
# 11          AUS                 Australia                 Australia
# 12          AUT                   Austria                   Austria
# ...

# %% [markdown]
# ### CountryNotes.csv

# %%
df_CountryNotes = pd.read_csv('Dataset-World-Bank/CountryNotes.csv')

# %%
print('Number of columns', len(df_CountryNotes.dtypes))
df_CountryNotes.dtypes
# Out:
# Number of columns 3
# Countrycode    object
# Seriescode     object
# Description    object
# dtype: object

# %%
print('shape: %d rows x %d columns' % df_CountryNotes.shape)
# Out:
# shape: 4857 rows x 3 columns

# %%
df_CountryNotes.head()
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
# 3         ABW        SM.POP.NETM
# 4         ABW        SM.POP.TOTL
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)
# 3  Data sources : United Nations World Population...
# 4  Estimates are derived from data on foreign-bor...

# %% [markdown]
# ### Footnotes.csv

# %%
df_FootNotes = pd.read_csv('Dataset-World-Bank/FootNotes.csv')

# %%
print('Number of columns', len(df_FootNotes.dtypes))
df_FootNotes.dtypes
# Out:
# Number of columns 4
# Countrycode    object
# Seriescode     object
# Year           object
# Description    object
# dtype: object

# %%
print('shape: %d rows x %d columns' % df_FootNotes.shape)
# Out:
# shape: 532415 rows x 4 columns

# %%
df_FootNotes.head()
# Out:
#   Countrycode         Seriescode    Year  \
# 0         ABW     AG.LND.FRST.K2  YR1990
# 1         ABW     AG.LND.FRST.K2  YR2000
# 2         ABW     AG.LND.FRST.K2  YR2005
# 3         ABW  BX.KLT.DINV.CD.WD  YR1987
# 4         ABW  BX.KLT.DINV.CD.WD  YR1988
#
#                                          Description
# 0                                      Not specified
# 1                                      Not specified
# 2                                      Not specified
# 3  Source: United Nations Conference on Trade and...
# 4  Source: United Nations Conference on Trade and...

# %% [markdown]
# ### Indicators.csv

# %%
df_Indicators = pd.read_csv('Dataset-World-Bank/Indicators.csv')

# %%
print('Number of columns', len(df_Indicators.dtypes))
df_Indicators.dtypes
# Out:
# Number of columns 6
# CountryName       object
# CountryCode       object
# IndicatorName     object
# IndicatorCode     object
# Year               int64
# Value            float64
# dtype: object

# %%
print('shape: %d rows x %d columns' % df_Indicators.shape)
# Out:
# shape: 5656458 rows x 6 columns

# %%
df_Indicators.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year     Value
# 0     SP.ADO.TFRT  1960       134
# 1     SP.POP.DPND  1960        88
# 2  SP.POP.DPND.OL  1960         7
# 3  SP.POP.DPND.YG  1960        81
# 4  MS.MIL.XPRT.KD  1960 3,000,000

# %%
pd.options.display.float_format = '{:,.0f}'.format
df_Indicators.describe()
# Out:
#            Year                  Value
# count 5,656,458              5,656,458
# mean      1,994      1,070,500,777,127
# std          14     48,424,694,452,642
# min       1,960 -9,824,821,297,572,060
# 25%       1,984                      6
# 50%       1,997                     64
# 75%       2,006             13,467,225
# max       2,015 11,033,666,000,000,000

# %%
df_Indicators.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             0
# Value            0
# dtype: int64

# %% [markdown]
# ### Series.csv

# %%
df_Series = pd.read_csv('Dataset-World-Bank/Series.csv')

# %%
print('Number of columns', len(df_Series.dtypes))
df_Series.dtypes
# Out:
# Number of columns 20
# SeriesCode                           object
# Topic                                object
# IndicatorName                        object
# ShortDefinition                      object
# LongDefinition                       object
# UnitOfMeasure                        object
# Periodicity                          object
# BasePeriod                           object
# OtherNotes                          float64
# AggregationMethod                    object
# LimitationsAndExceptions             object
# NotesFromOriginalSource              object
# GeneralComments                      object
# Source                               object
# StatisticalConceptAndMethodology     object
# DevelopmentRelevance                 object
# RelatedSourceLinks                   object
# OtherWebLinks                       float64
# RelatedIndicators                   float64
# LicenseType                          object
# dtype: object

# %%
print('shape: %d rows x %d columns' % df_Series.shape)
# Out:
# shape: 1345 rows x 20 columns

# %%
df_Series.head()
# Out:
#              SeriesCode                                              Topic  \
# 0        BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1  BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2     BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3     BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4        BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
#
#                                        IndicatorName ShortDefinition  \
# 0  Foreign direct investment, net (BoP, current US$)             NaN
# 1  Foreign direct investment, net inflows (% of GDP)             NaN
# 2  Foreign direct investment, net inflows (BoP, c...             NaN
# 3  Foreign direct investment, net outflows (% of ...             NaN
# 4             Net capital account (BoP, current US$)             NaN
#
#                                       LongDefinition UnitOfMeasure  \
# ...

# %% [markdown]
# ### SeriesNotes.csv

# %%
df_SeriesNotes = pd.read_csv('Dataset-World-Bank/SeriesNotes.csv')

# %%
print('Number of columns', len(df_SeriesNotes.dtypes))
df_SeriesNotes.dtypes
# Out:
# Number of columns 3
# Seriescode     object
# Year           object
# Description    object
# dtype: object

# %%
print('shape: %d rows x %d columns' % df_SeriesNotes.shape)
# Out:
# shape: 369 rows x 3 columns

# %%
df_SeriesNotes.head()
# Out:
#           Seriescode    Year  \
# 0        SP.ADO.TFRT  YR1960
# 1     SP.DYN.AMRT.FE  YR1960
# 2     SP.DYN.AMRT.MA  YR1960
# 3  SP.DYN.TO65.FE.ZS  YR1960
# 4  SP.DYN.TO65.MA.ZS  YR1960
#
#                                          Description
# 0         Interpolated using data for 1957 and 1962.
# 1  Interpolated using data for 1957 and 1962, if ...
# 2  Interpolated using data for 1957 and 1962, if ...
# 3         Interpolated using data for 1957 and 1962.
# 4         Interpolated using data for 1957 and 1962.

# %% [markdown]
# ### All unique indicators

# %%
df2 = df_Indicators[['IndicatorCode','IndicatorName']] \
    .drop_duplicates() \
    .set_index('IndicatorCode') \
    .sort_index()
df2
# Out:
#                                                               IndicatorName
# IndicatorCode
# AG.AGR.TRAC.NO                             Agricultural machinery, tractors
# AG.CON.FERT.PT.ZS         Fertilizer consumption (% of fertilizer produc...
# AG.CON.FERT.ZS            Fertilizer consumption (kilograms per hectare ...
# AG.LND.AGRI.K2                                   Agricultural land (sq. km)
# AG.LND.AGRI.ZS                           Agricultural land (% of land area)
# AG.LND.ARBL.HA                                       Arable land (hectares)
# AG.LND.ARBL.HA.PC                         Arable land (hectares per person)
# AG.LND.ARBL.ZS                                 Arable land (% of land area)
# AG.LND.CREL.HA                      Land under cereal production (hectares)
# AG.LND.CROP.ZS                          Permanent cropland (% of land area)
# AG.LND.EL5M.ZS            Land area where elevation is below 5 meters (%...
# ...

# %%
df3 = df_Series[['SeriesCode','Topic','IndicatorName','LongDefinition']] \
    .set_index('SeriesCode') \
    .sort_index()
df3
# Out:
#                                                                       Topic  \
# SeriesCode
# AG.AGR.TRAC.NO                         Environment: Agricultural production
# AG.CON.FERT.PT.ZS                      Environment: Agricultural production
# AG.CON.FERT.ZS                         Environment: Agricultural production
# AG.LND.AGRI.K2                                        Environment: Land use
# AG.LND.AGRI.ZS                                        Environment: Land use
# AG.LND.ARBL.HA                                        Environment: Land use
# AG.LND.ARBL.HA.PC                                     Environment: Land use
# AG.LND.ARBL.ZS                                        Environment: Land use
# AG.LND.CREL.HA                         Environment: Agricultural production
# AG.LND.CROP.ZS                                        Environment: Land use
# AG.LND.EL5M.ZS                                        Environment: Land use
# ...

# %%
df3[~df3.index.isin(df2.index)]
# Out:
#                                                     Topic  \
# SeriesCode
# IC.LGL.PROC  Private Sector & Trade: Business environment
#
#                                          IndicatorName  \
# SeriesCode
# IC.LGL.PROC  Procedures to enforce a contract (number)
#
#                                                 LongDefinition
# SeriesCode
# IC.LGL.PROC  Number of procedures to enforce a contract are...

# %% [markdown]
# # Aantal indicators per jaar

# %%
df_Indicators_per_Year = df_Indicators['IndicatorCode'].groupby(df_Indicators['Year']).count()
df_Indicators_per_Year
# Out:
# Year
# 1960     23188
# 1961     26617
# 1962     28439
# 1963     28625
# 1964     29128
# 1965     32035
# 1966     31337
# 1967     32737
# 1968     32546
# 1969     33007
# 1970     62540
# 1971     68277
# 1972     69901
# 1973     69373
# 1974     70105
# 1975     72550
# 1976     73430
# 1977     75747
# 1978     75628
# 1979     75904
# 1980     81456
# 1981     84374
# 1982     85169
# 1983     85282
# 1984     85973
# 1985     87486
# 1986     87972
# 1987     89397
# 1988     89441
# 1989     92738
# 1990    117634
# 1991    115838
# 1992    121627
# 1993    123699
# 1994    125905
# 1995    134616
# 1996    135125
# 1997    136377
# 1998    137381
# 1999    142408
# 2000    154728
# 2001    150456
# 2002    154958
# 2003    153468
# 2004    158011
# 2005    180506
# 2006    177119
# 2007    180354
# 2008    179825
# 2009    178578
# 2010    187206
# 2011    176063
# 2012    175147
# 2013    156876
# 2014    107389
# 2015     14762
# Name: IndicatorCode, dtype: int64

# %%
df_IndicatorsFull = df_Indicators.merge(df_Country, on='CountryCode')
df_IndicatorsFull.head()
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# 5        Arab World         ARB
# 6        Arab World         ARB
# 7        Arab World         ARB
# 8        Arab World         ARB
# 9        Arab World         ARB
# 10       Arab World         ARB
# 11       Arab World         ARB
# 12       Arab World         ARB
# 13       Arab World         ARB
# 14       Arab World         ARB
# 15       Arab World         ARB
# 16       Arab World         ARB
# 17       Arab World         ARB
# 18       Arab World         ARB
# 19       Arab World         ARB
# 20       Arab World         ARB
# 21       Arab World         ARB
# 22       Arab World         ARB
# 23       Arab World         ARB
# 24       Arab World         ARB
# 25       Arab World         ARB
# 26       Arab World         ARB
# 27       Arab World         ARB
# ...

# %%
# df_Country.set_index('CountryCode', inplace=True)
df_Country
# Out:
#     CountryCode                 ShortName                 TableName  \
# 0           AFG               Afghanistan               Afghanistan
# 1           ALB                   Albania                   Albania
# 2           DZA                   Algeria                   Algeria
# 3           ASM            American Samoa            American Samoa
# 4           ADO                   Andorra                   Andorra
# 5           AGO                    Angola                    Angola
# 6           ATG       Antigua and Barbuda       Antigua and Barbuda
# 7           ARB                Arab World                Arab World
# 8           ARG                 Argentina                 Argentina
# 9           ARM                   Armenia                   Armenia
# 10          ABW                     Aruba                     Aruba
# 11          AUS                 Australia                 Australia
# 12          AUT                   Austria                   Austria
# ...

# %%
df_Indicators['CountryCode'].map(df_Country['Region'])

df_ECA = df_Indicators[df_Indicators['Region']=='Europe & Central Asia']

# %%
df_ECA.shape
# Out:
# (1113747, 7)

# %%
# df_Indicators[df_Indicators['CountryCode']=='NLD']
# df_Indicators[['CountryName','IndicatorName','Year','Value']]

df_Indicators.loc[df_Indicators['CountryCode']=='NLD', ['CountryName','IndicatorName','Year','Value']]

# df_Indicators_per_Year = df_Indicators['IndicatorCode'].groupby(df_Indicators['Year']).count()
# df_Indicators_per_Year
# Out:
#          CountryName                                      IndicatorName  Year  \
# 16035    Netherlands  Adolescent fertility rate (births per 1,000 wo...  1960
# 16036    Netherlands  Age dependency ratio (% of working-age populat...  1960
# 16037    Netherlands  Age dependency ratio, old (% of working-age po...  1960
# 16038    Netherlands  Age dependency ratio, young (% of working-age ...  1960
# 16039    Netherlands  Alternative and nuclear energy (% of total ene...  1960
# 16040    Netherlands        Arms exports (SIPRI trend indicator values)  1960
# 16041    Netherlands        Arms imports (SIPRI trend indicator values)  1960
# 16042    Netherlands               Birth rate, crude (per 1,000 people)  1960
# 16043    Netherlands             CO2 emissions (kg per 2005 US$ of GDP)  1960
# 16044    Netherlands                                 CO2 emissions (kt)  1960
# 16045    Netherlands             CO2 emissions (metric tons per capita)  1960
# ...

# %%
plt.plot(df_Indicators_per_Year)

# %% [markdown]
# ### Empty Values

# %%
df_Indicators.isna().sum()
# Out:
# CountryName      0
# CountryCode      0
# IndicatorName    0
# IndicatorCode    0
# Year             0
# Value            0
# dtype: int64

# %%
df_Indicators.head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
df_Indicators.describe()
# Out:
#                Year         Value
# count  5.656458e+06  5.656458e+06
# mean   1.994464e+03  1.070501e+12
# std    1.387895e+01  4.842469e+13
# min    1.960000e+03 -9.824821e+15
# 25%    1.984000e+03  5.566242e+00
# 50%    1.997000e+03  6.357450e+01
# 75%    2.006000e+03  1.346722e+07
# max    2.015000e+03  1.103367e+16

# %% [markdown]
# # Mobile subscriptions

# %%
df_Series[df_Series['IndicatorName'].str.contains('Mobile')]
# Out:
#          SeriesCode                           Topic  \
# 913     IT.CEL.SETS  Infrastructure: Communications
# 914  IT.CEL.SETS.P2  Infrastructure: Communications
#
#                                       IndicatorName ShortDefinition  \
# 913                   Mobile cellular subscriptions             NaN
# 914  Mobile cellular subscriptions (per 100 people)             NaN
#
#                                         LongDefinition UnitOfMeasure  \
# 913  Mobile cellular telephone subscriptions are su...           NaN
# 914  Mobile cellular telephone subscriptions are su...           NaN
#
#     Periodicity BasePeriod  OtherNotes AggregationMethod  \
# 913      Annual        NaN         NaN               Sum
# 914      Annual        NaN         NaN  Weighted average
#
#                               LimitationsAndExceptions  \
# 913  Operators have traditionally been the main sou...
# 914  Operators have traditionally been the main sou...
#
#     NotesFromOriginalSource  \
# ...

# %%
df_MobileSubscriptions = df_Indicators[(df_Indicators['IndicatorCode']=='IT.CEL.SETS')]
df_MobileSubscriptions.head()
# Out:
#                                  CountryName CountryCode  \
# 48                                Arab World         ARB
# 129                   Caribbean small states         CSS
# 209           Central Europe and the Baltics         CEB
# 308  East Asia & Pacific (all income levels)         EAS
# 428    East Asia & Pacific (developing only)         EAP
#
#                      IndicatorName IndicatorCode  Year  Value
# 48   Mobile cellular subscriptions   IT.CEL.SETS  1960    0.0
# 129  Mobile cellular subscriptions   IT.CEL.SETS  1960    0.0
# 209  Mobile cellular subscriptions   IT.CEL.SETS  1960    0.0
# 308  Mobile cellular subscriptions   IT.CEL.SETS  1960    0.0
# 428  Mobile cellular subscriptions   IT.CEL.SETS  1960    0.0

# %%
df_Euro = df_MobileSubscriptions[df_MobileSubscriptions['CountryCode']=='EMU']
df_EastAsia = df_MobileSubscriptions[df_MobileSubscriptions['CountryCode']=='EAS']

plt.plot(df_Euro['Year'], df_Euro['Value'], marker='o')
plt.plot(df_EastAsia['Year'], df_EastAsia['Value'], marker='+')
plt.show()
